# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
# import matplotlib
# matplotlib.use("Agg")
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
t1 = Table(fitsio.read('/Users/rongpu/Documents/Data/desi_targets/dr9.0/lrg_xcorr/magnification/lrg_magnification_parent_north.fits'))

# %%
t2 = Table(fitsio.read('/Users/rongpu/Documents/Data/desi_targets/dr9.0/lrg_xcorr/magnification/lrg_magnification_north.fits', columns=['RELEASE', 'BRICKID', 'OBJID']))

# %%
t1['id'] = np.array(t1['OBJID'], dtype='int64') * int(1e10) \
          + np.array(t1['BRICKID'], dtype='int64') * int(1e4) \
          + np.array(t1['RELEASE'], dtype='int64')

t2['id'] = np.array(t2['OBJID'], dtype='int64') * int(1e10) \
          + np.array(t2['BRICKID'], dtype='int64') * int(1e4) \
          + np.array(t2['RELEASE'], dtype='int64')

# %%
len(t1)==len(t2)
# Out:
# True

# %%
t1.sort('id')
t2.sort('id')

# %%
np.all(t1['id']==t2['id'])
# Out:
# True

# %%
tt = Table(fitsio.read('/Users/rongpu/Documents/Data/desi_targets/dr9.0/lrg_xcorr/magnification/lrg_magnification_north.fits', rows=[0]))

# %%
np.in1d(t1.colnames, tt.colnames)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False])

# %%
tt = Table(fitsio.read('/Users/rongpu/Documents/Data/lrg_xcorr/magnification/lrg_magnification_pz_north_0.99.fits', rows=[0]))

# %%
tt
# Out:
# <Table length=1>
# RELEASE BRICKID OBJID Z_PHOT_MEAN ... Z_PHOT_U68 Z_PHOT_L95 Z_PHOT_U95 KFOLD
#  int16   int32  int32   float32   ...  float32    float32    float32   int16
# ------- ------- ----- ----------- ... ---------- ---------- ---------- -----
#    9011  326196    54  0.63688344 ...  0.6629308 0.58451325  0.6979729     2

# %%
np.array(t1.colnames)[~np.in1d(t1.colnames, tt.colnames)]
# Out:
# array(['id'], dtype='<U18')

# %%
t1.colnames
# Out:
# ['RELEASE',
#  'BRICKID',
#  'OBJID',
#  'RA',
#  'DEC',
#  'EBV',
#  'FLUX_G',
#  'FLUX_R',
#  'FLUX_Z',
#  'FLUX_W1',
#  'MW_TRANSMISSION_G',
#  'MW_TRANSMISSION_R',
#  'MW_TRANSMISSION_Z',
#  'MW_TRANSMISSION_W1',
#  'NOBS_G',
#  'NOBS_R',
#  'NOBS_Z',
#  'FIBERFLUX_Z',
#  'MASKBITS',
#  'TARGETID',
#  'id']

# %%
tt.colnames
# Out:
# ['RELEASE',
#  'BRICKID',
#  'OBJID',
#  'TYPE',
#  'RA',
#  'DEC',
#  'DCHISQ',
#  'EBV',
#  'FLUX_G',
#  'FLUX_R',
#  'FLUX_Z',
#  'FLUX_W1',
#  'FLUX_W2',
#  'FLUX_IVAR_G',
#  'FLUX_IVAR_R',
#  'FLUX_IVAR_Z',
#  'FLUX_IVAR_W1',
#  'FLUX_IVAR_W2',
#  'MW_TRANSMISSION_G',
#  'MW_TRANSMISSION_R',
#  'MW_TRANSMISSION_Z',
#  'MW_TRANSMISSION_W1',
#  'MW_TRANSMISSION_W2',
#  'NOBS_G',
#  'NOBS_R',
#  'NOBS_Z',
#  'SHAPE_R',
#  'SHAPE_R_IVAR',
#  'SHAPE_E1',
#  'SHAPE_E2',
#  'FIBERFLUX_Z',
#  'FIBERTOTFLUX_Z',
#  'GAIA_PHOT_G_MEAN_MAG',
#  'MASKBITS',
#  'Z_PHOT_MEAN',
#  'Z_PHOT_MEDIAN',
#  'Z_PHOT_STD',
#  'Z_PHOT_L68',
#  'Z_PHOT_U68',
#  'Z_PHOT_L95',
#  'Z_PHOT_U95',
#  'Z_SPEC',
#  'SURVEY',
#  'TRAINING',
#  'KFOLD']

# %%
len(t1)
# Out:
# 9552442

# %%
len(t2)
# Out:
# 9552442

# %%
tt = Table(fitsio.read('/Users/rongpu/Documents/Data/desi_targets/dr9.0/lrg_xcorr/magnification/lrg_magnification_north.fits', rows=[0]))

# %%
t1
# Out:
# <Table length=9552442>
# RELEASE BRICKID OBJID ... FIBERFLUX_Z MASKBITS      TARGETID
#  int16   int32  int32 ...   float32    int16         int64
# ------- ------- ----- ... ----------- -------- -----------------
#    9010   37302   426 ...   17.107004        0 39626555520975274
#    9010   37302   684 ...   4.1262374        0 39626555520975532
#    9010   37302   779 ...    8.518037        0 39626555520975627
#    9010   37302   952 ...   6.7477045        0 39626555520975800
#    9010   37302  1237 ...    8.482392        0 39626555520976085
#    9010   37302  1488 ...   2.7285674        0 39626555520976336
#    9010   37302  1630 ...    8.092041     2048 39626555520976478
#    9010   37302  2320 ...   15.040966        0 39626555520977168
#    9010   37302  2746 ...    2.204888        0 39626555520977594
#    9010   37302  3171 ...   18.375439        0 39626555520978019
#     ...     ...   ... ...         ...      ...               ...
# ...
