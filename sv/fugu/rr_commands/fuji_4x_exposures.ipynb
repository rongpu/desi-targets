# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
# import matplotlib
# matplotlib.use("Agg")
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
cat = Table(fitsio.read('/global/cfs/cdirs/desi/spectro/redux/fuji/exposures-fuji.fits', ext='EXPOSURES'))
print(len(cat), len(np.unique(cat['EXPID'])))
# Out:
# 2470 2470

# %%
subsamp_dict = {'80605': [[73702, 74779, 68291, 74780, 68292, 74782, 67972]],
 '80606': [[67970, 68813, 68285, 68289, 68630, 67968, 67971]],
 '80607': [[67767, 68028, 68847, 68664, 68845, 68846],
  [67765, 68662, 68663, 68027, 67766, 68666]],
 '80608': [[68842, 69252, 68023, 68024, 68661],
  [69253, 68491, 67769, 69249, 67770, 68328, 67771],
  [68660, 68327, 68317, 68025, 68841]],
 '80609': [[68490, 68339, 68337, 68334, 68065, 68336],
  [67781, 68063, 68064, 67783, 68340, 68489, 68338]],
 '80610': [[68332, 68478, 68041, 68330, 68488, 68683, 75114],
  [75113, 68477, 68040, 68333, 68331, 68042, 75116]],
 '80613': [[69226, 68658, 69230, 69228],
  [81833, 81834],
  [81835, 69227, 68657],
  [69229, 81832, 69225, 68659, 81831]]}

# %%
# exp_list = sorted([i for k in subsamp_dict.values() for j in k for i in j])
# print(len(exp_list), len(np.unique(exp_list)))

# mask = np.in1d(cat['EXPID'], exp_list)
# print(np.sum(mask))
# # cat[mask]

# %%
# mask_bgs = cat['TILEID']==80613
# mask_bgs &= cat['BGS_EFFTIME_BRIGHT']/cat['EXPTIME'] > 0.2

# mask_dark = cat['TILEID']!=80613
# mask_dark &= cat['EFFTIME_SPEC']/cat['EXPTIME'] > 0.3

# mask = mask_bgs | mask_dark
# cat = cat[mask]
# print(len(cat))

# %%
print('                 ELG_EFFTIME_DARK  BGS_EFFTIME_BRIGHT   EFFTIME_DARK_GFA   EFFTIME_BRIGHT_GFA')
print()

# for tileid in subsamp_dict.keys():
for tileid_str in ['80605', '80607', '80609', '80606', '80608', '80610', '80613']:
    tileid = int(tileid_str)
    mask = cat['TILEID']==tileid
    print(cat['FAPRGRM'][mask][0].upper(), tileid)
    for subset_index, exp_list in enumerate(subsamp_dict[tileid_str]):
        # print(exp_list)
        mask = np.in1d(cat['EXPID'], exp_list)
        if np.sum(mask)>1:
            print_str = 'exposures'
        else:
            print_str = 'exposure '
        print('subset {}: {} {} {:11.0f} {:19.0f} {:18.0f} {:20.0f}'.format(subset_index+1, np.sum(mask), print_str, np.sum(cat['ELG_EFFTIME_DARK'][mask]), np.sum(cat['BGS_EFFTIME_BRIGHT'][mask]), np.sum(cat['EFFTIME_DARK_GFA'][mask]), np.sum(cat['EFFTIME_BRIGHT_GFA'][mask])))
    print()
# Out:
#                  ELG_EFFTIME_DARK  BGS_EFFTIME_BRIGHT   EFFTIME_DARK_GFA   EFFTIME_BRIGHT_GFA
#
# LRGQSO 80605
# subset 1: 7 exposures        3480                3536                  0                    0
#
# LRGQSO 80607
# subset 1: 6 exposures        4046                3692                  0                    0
# subset 2: 6 exposures        3960                3604                  0                    0
#
# LRGQSO 80609
# subset 1: 6 exposures        3804                3913                  0                    0
# subset 2: 7 exposures        3496                3595                  0                    0
#
# ELG 80606
# subset 1: 7 exposures        4001                3901                  0                    0
#
# ELG 80608
# subset 1: 5 exposures        4006                3591                  0                    0
# subset 2: 7 exposures        4531                4125                  0                    0
# subset 3: 5 exposures        4297                3948                  0                    0
#
# ELG 80610
# subset 1: 7 exposures        3989                3924                  0                    0
# subset 2: 7 exposures        4126                4077                  0                    0
#
# BGSMWS 80613
# subset 1: 4 exposures         725                 672                  0                    0
# subset 2: 2 exposures         782                 683                  0                    0
# subset 3: 3 exposures         785                 709                  0                    0
# subset 4: 5 exposures         743                 681                  0                    0

# %%
# Print summary
# for tileid_str in subsamp_dict.keys():
for tileid_str in ['80605', '80607', '80609', '80606', '80608', '80610', '80613']:
    tileid = int(tileid_str)
    mask = cat['TILEID']==tileid
    tile_flavor = cat['FAPRGRM'][mask][0].upper()
    n_exp = np.sum(mask)
    if tileid==80613:
        nom_depth = 180.
        depth_col = 'BGS_EFFTIME_BRIGHT'
    else:
        nom_depth = 1000.
        depth_col = 'EFFTIME_SPEC'
    tot_depth = np.sum(cat[depth_col][mask])
    print('Tile {} ({}):'.format(tileid, tile_flavor))
    print('all:       n_exp={:2}  {}={:5.0f}s'.format(n_exp, depth_col, tot_depth))
    subsets = subsamp_dict[tileid_str]
    for index, subset in enumerate(subsets):
        mask = np.in1d(cat['EXPID'], subset)
        subset_depth = np.sum(cat[depth_col][mask])
        print('subset {}:  n_exp={:2}  {}={:5.0f}s'.format(index+1, len(subset), depth_col, subset_depth))
    mask = (cat['TILEID']==tileid) & (~np.in1d(cat['EXPID'], np.concatenate(subsets)))
    unused_depth = np.sum(cat[depth_col][mask])
    print('unused:    n_exp={:2}  {}={:5.0f}s'.format(np.sum(mask), depth_col, unused_depth))
    print()
# Out:
# Tile 80605 (LRGQSO):
# all:       n_exp=24  EFFTIME_SPEC= 6872s
# subset 1:  n_exp= 7  EFFTIME_SPEC= 3480s
# unused:    n_exp=17  EFFTIME_SPEC= 3393s
#
# Tile 80607 (LRGQSO):
# all:       n_exp=15  EFFTIME_SPEC= 9374s
# subset 1:  n_exp= 6  EFFTIME_SPEC= 4046s
# subset 2:  n_exp= 6  EFFTIME_SPEC= 3960s
# unused:    n_exp= 3  EFFTIME_SPEC= 1368s
#
# Tile 80609 (LRGQSO):
# all:       n_exp=15  EFFTIME_SPEC= 7819s
# subset 1:  n_exp= 6  EFFTIME_SPEC= 3804s
# subset 2:  n_exp= 7  EFFTIME_SPEC= 3496s
# unused:    n_exp= 2  EFFTIME_SPEC=  519s
#
# Tile 80606 (ELG):
# all:       n_exp=12  EFFTIME_SPEC= 6692s
# subset 1:  n_exp= 7  EFFTIME_SPEC= 4001s
# unused:    n_exp= 5  EFFTIME_SPEC= 2692s
#
# Tile 80608 (ELG):
# all:       n_exp=23  EFFTIME_SPEC=15160s
# subset 1:  n_exp= 5  EFFTIME_SPEC= 4006s
# subset 2:  n_exp= 7  EFFTIME_SPEC= 4531s
# subset 3:  n_exp= 5  EFFTIME_SPEC= 4297s
# unused:    n_exp= 6  EFFTIME_SPEC= 2327s
#
# Tile 80610 (ELG):
# all:       n_exp=16  EFFTIME_SPEC= 9517s
# subset 1:  n_exp= 7  EFFTIME_SPEC= 3989s
# subset 2:  n_exp= 7  EFFTIME_SPEC= 4126s
# unused:    n_exp= 2  EFFTIME_SPEC= 1402s
#
# Tile 80613 (BGSMWS):
# all:       n_exp=30  BGS_EFFTIME_BRIGHT= 3050s
# subset 1:  n_exp= 4  BGS_EFFTIME_BRIGHT=  672s
# subset 2:  n_exp= 2  BGS_EFFTIME_BRIGHT=  683s
# subset 3:  n_exp= 3  BGS_EFFTIME_BRIGHT=  709s
# subset 4:  n_exp= 5  BGS_EFFTIME_BRIGHT=  681s
# unused:    n_exp=16  BGS_EFFTIME_BRIGHT=  306s
