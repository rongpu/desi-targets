# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
# import matplotlib
# matplotlib.use("Agg")
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
fn = '/global/cfs/cdirs/desi/spectro/redux/fuji/tiles/perexp/80702/00079560/redrock-1-80702-exp00079560.fits'
fits = fitsio.FITS(fn)
print(fits)
print()

for index in range(len(fits)):
    print(fits[index].get_extname())
    data = Table(fitsio.read(fn, ext=index))
    print(data.colnames)
    print()
# Out:
#   file: /global/cfs/cdirs/desi/spectro/redux/fuji/tiles/perexp/80702/00079560/redrock-1-80702-exp00079560.fits
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU
#   1      BINARY_TBL      REDSHIFTS
#   2      BINARY_TBL      FIBERMAP
#   3      BINARY_TBL      EXP_FIBERMAP
#   4      BINARY_TBL      TSNR2
#
#
# []
#
# REDSHIFTS
# ['TARGETID', 'Z', 'ZERR', 'ZWARN', 'CHI2', 'COEFF', 'NPIXELS', 'SPECTYPE', 'SUBTYPE', 'NCOEFF', 'DELTACHI2']
#
# FIBERMAP
# ...

# %%
fn = '/global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1295/20210618/redrock-0-1295-thru20210618.fits	'
fits = fitsio.FITS(fn)
print(fits)
print()

for index in range(len(fits)):
    print(fits[index].get_extname())
    data = Table(fitsio.read(fn, ext=index))
    print(data.colnames)
    print()
# Out:
#   file: /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1295/20210618/redrock-0-1295-thru20210618.fits
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU
#   1      BINARY_TBL      REDSHIFTS
#   2      BINARY_TBL      FIBERMAP
#   3      BINARY_TBL      EXP_FIBERMAP
#   4      BINARY_TBL      TSNR2
#
#
# []
#
# REDSHIFTS
# ['TARGETID', 'Z', 'ZERR', 'ZWARN', 'CHI2', 'COEFF', 'NPIXELS', 'SPECTYPE', 'SUBTYPE', 'NCOEFF', 'DELTACHI2']
#
# FIBERMAP
# ...
