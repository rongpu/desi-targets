# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
# import matplotlib
# matplotlib.use("Agg")
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
tt = Table.read('/Users/rongpu/git/desi-targets/sv/everest/rr_commands/low_speed_coadds.txt', format='ascii.commented_header')

# %%
tt
# Out:
# <Table length=6>
# TILEID  NEXP ...                EXPIDS
# int64  int64 ...                str35
# ------ ----- ... -----------------------------------
#  80605     5 ...       67972,67974,67987,73704,73705
#  80605     4 ...             67973,67975,71594,73702
#  80608     6 ... 67771,68013,68491,68492,69625,69626
#  80608     4 ...             67771,68013,68024,68492
#  80609     4 ...             67781,67782,67783,67784
#  80610     4 ...             68039,68041,68331,68478

# %%
80605, 80608
