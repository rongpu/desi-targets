# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
# import matplotlib
# matplotlib.use("Agg")
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
exp = Table.read('/global/cfs/cdirs/desi/users/rongpu/spectro/sv1/sv1-exposures_20210224.fits')
print(len(exp), len(np.unique(exp['EXPID'])))
# Out:
# 1243 1243

# %%
exp[:1]
# Out:
# <Table length=1>
#  NIGHT   EXPID  FIELD  ... EPHEM_MOON_ILLUM_FRAC EPHEM_NEAREST_FULL_MOON
#  int64   int64 bytes30 ...        float64                float64
# -------- ----- ------- ... --------------------- -----------------------
# 20201214 67710 XMM-LSS ...  0.005432771706774475      14.852906347514363

# %%
exp_dict = {'80605': [[73702, 74779, 68291, 74780, 68292, 74782, 67972]],
 '80606': [[67970, 68813, 68285, 68289, 68630, 67968, 67971]],
 '80607': [[67767, 68028, 68847, 68664, 68845, 68846],
  [67765, 68662, 68663, 68027, 67766, 68666]],
 '80608': [[68842, 69252, 68023, 68024, 68661],
  [69253, 68491, 67769, 69249, 67770, 68328, 67771],
  [68660, 68327, 68317, 68025, 68841]],
 '80609': [[68490, 68339, 68337, 68334, 68065, 68336],
  [67781, 68063, 68064, 67783, 68340, 68489, 68338]],
 '80610': [[68332, 68478, 68041, 68330, 68488, 68683, 75114],
  [75113, 68477, 68040, 68333, 68331, 68042, 75116]],
 '80613': [[69228, 68659],
  [68658, 69229],
  [68657],
  [69227, 69226, 69230, 69225]]}

# %%
exp_list = sorted([i for k in exp_dict.values() for j in k for i in j])
print(len(exp_list), len(np.unique(exp_list)))

mask = np.in1d(exp['EXPID'], exp_list)
print(np.sum(mask))
exp[mask]
# Out:
# 79 79
# 79
# <Table length=79>
#  NIGHT   EXPID  FIELD  ... EPHEM_MOON_ILLUM_FRAC EPHEM_NEAREST_FULL_MOON
#  int64   int64 bytes30 ...        float64                float64
# -------- ----- ------- ... --------------------- -----------------------
# 20201214 67765    Lynx ...  0.005432771706774475      14.852906347514363
# 20201214 67766    Lynx ...  0.005432771706774475      14.852906347514363
# 20201214 67767    Lynx ...  0.005432771706774475      14.852906347514363
# 20201214 67769    Lynx ...  0.005432771706774475      14.852906347514363
# 20201214 67770    Lynx ...  0.005432771706774475      14.852906347514363
# 20201214 67771    Lynx ...  0.005432771706774475      14.852906347514363
# 20201214 67781  COSMOS ...  0.005432771706774475      14.852906347514363
# 20201214 67783  COSMOS ...  0.005432771706774475      14.852906347514363
# 20201215 67968 XMM-LSS ...   0.03578269411813284      13.852906347514363
# 20201215 67970 XMM-LSS ...   0.03578269411813284      13.852906347514363
#      ...   ...     ... ...                   ...                     ...
# 20201221 69249    Lynx ...      0.53179038130009       7.852906347514363
# 20201221 69252    Lynx ...      0.53179038130009       7.852906347514363
# 20201221 69253    Lynx ...      0.53179038130009       7.852906347514363
# 20210130 73702 XMM-LSS ...    0.9240972643116383      -2.488749969546916
# 20210205 74779 XMM-LSS ...    0.3272244430091585      -8.488749969546916
# 20210205 74780 XMM-LSS ...    0.3272244430091585      -8.488749969546916
# 20210205 74782 XMM-LSS ...    0.3272244430091585      -8.488749969546916
# 20210208 75113  COSMOS ...   0.07259350042555102     -11.488749969546916
# 20210208 75114  COSMOS ...   0.07259350042555102     -11.488749969546916
# 20210208 75116  COSMOS ...   0.07259350042555102     -11.488749969546916

# %%
print('               R_DEPTH_EBVAIR  R_DEPTH')
print()

# for tileid in exp_dict.keys():
for tileid in ['80605', '80607', '80609', '80606', '80608', '80610', '80613']:
    mask = exp['TILEID']==int(tileid)
    print(exp['TARGETS'][mask][0].upper(), tileid)
    for subset_index, exp_list in enumerate(exp_dict[tileid]):
        mask = np.in1d(exp['EXPID'], exp_list)
        if np.sum(mask)>1:
            print_str = 'exposures'
        else:
            print_str = 'exposure '
        print('subset {}: {} {} {:7.0f} {:8.0f}'.format(subset_index+1, np.sum(mask), print_str, np.sum(exp['R_DEPTH_EBVAIR'][mask]), np.sum(exp['R_DEPTH'][mask])))
    print()
# Out:
#                R_DEPTH_EBVAIR  R_DEPTH
#
# QSO+LRG 80605
# subset 1: 7 exposures    3946     4746
#
# QSO+LRG 80607
# subset 1: 6 exposures    4055     5169
# subset 2: 6 exposures    3970     5063
#
# QSO+LRG 80609
# subset 1: 6 exposures    3524     4002
# subset 2: 7 exposures    3488     3968
#
# ELG 80606
# subset 1: 7 exposures    4045     4729
#
# ELG 80608
# subset 1: 5 exposures    3885     4975
# subset 2: 7 exposures    4012     5140
# subset 3: 5 exposures    4095     5255
#
# ELG 80610
# subset 1: 7 exposures    3910     4449
# subset 2: 7 exposures    3865     4387
#
# BGS+MWS 80613
# subset 1: 2 exposures     581      768
# subset 2: 2 exposures     636      838
# subset 3: 1 exposure      512      667
# subset 4: 4 exposures     655      914
