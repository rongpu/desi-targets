# %% [markdown]
# Predict the DECam z mag and GAIA G mag using 2MASS and Tycho2 magnitudes

# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
# import matplotlib
# matplotlib.use("Agg")
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio
# from astropy.io import fits

# %%
params = {'legend.fontsize': 'large',
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
nmad = lambda x: 1.4826 * np.median(np.abs(x-np.median(x)))

# %%
gaia = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/useful/gaia_edr3_g_14_pm_dr9.fits'))

mask = gaia['PHOT_G_MEAN_MAG']<12
print(np.sum(mask)/len(mask))
gaia = gaia[mask]

# Coefficients for EDR3
coeffs = dict(
    g = [-0.1125681175, 0.3506376997, 0.9082025788, -1.0078309266,
        -1.4212131445, 4.5685722177, -4.5719415419, 2.3816887292,
        -0.7162270722, 0.1247021438, -0.0114938710, 0.0003949585,
        0.0000051647],
    r = [0.1431278873, -0.2999797766, -0.0553379742, 0.1544273115,
        0.3068634689, -0.9499143903, 0.9769739362, -0.4926704528,
        0.1272539574, -0.0133178183, -0.0008153813, 0.0003094116,
        -0.0000198891],
    z = [0.5173814296, -1.0450176704, 0.1529797809, 0.1856005222,
        -0.2366580132, 0.1018331214, -0.0189673240, 0.0012988354])

bprp_min, bprp_max = -0.5, 4.7

for i, band in enumerate(['g', 'r', 'z']):
    mag = np.copy(gaia['PHOT_G_MEAN_MAG'])
    for order, c in enumerate(coeffs[band]):
        x = gaia['PHOT_BP_MEAN_MAG']-gaia['PHOT_RP_MEAN_MAG']
        x = np.clip(x, bprp_min, bprp_max)
        mag += c * (x)**order
    gaia['decam_mag_'+band] = mag
    
mask = (gaia['PHOT_BP_MEAN_MAG']==0) | (gaia['PHOT_RP_MEAN_MAG']==0)
for band in ['g', 'r', 'z']:
    gaia['decam_mag_'+band][mask] = np.nan
# Out:
# 0.22808040302272004

# %%
tycho2 = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/useful/Tycho-2-dr9.fits'))

mask = tycho2['VTmag']<10
tycho2 = tycho2[mask]
print(len(tycho2))
# Out:
# 126232

# %%
twomass = Table(fitsio.read('/global/cfs/cdirs/desi/users/rongpu/useful/2mass_psc/2mass_psc_j_12-dr9.fits'))

mask = twomass['Jmag']<11
twomass = twomass[mask]
print(len(twomass))
# Out:
# 1132120

# %%
gaia['RA2000'] = gaia['RA'] - 16 * gaia['PMRA'] * 1e-3/3600 / np.cos(np.radians(gaia['DEC']))
gaia['DEC2000'] = gaia['DEC'] - 16 * gaia['PMDEC'] * 1e-3/3600

# %%
sys.path.append(os.path.expanduser('~/git/Python/user_modules/'))
from match_coord import match_coord

idx1, idx2, d2d, d_ra, d_dec = match_coord(gaia['RA2000'], gaia['DEC2000'], tycho2['RA'], tycho2['DEC'], search_radius=0.5, plot_q=True)
print(len(idx1)/len(gaia))
print(len(idx1)/len(tycho2))
# Out:
# Doubly matched objects = 353
# Final matched objects = 124668
# 0.13565378622352603
# 0.987610114709424

# %%
gaia = gaia[idx1]
tycho2 = tycho2[idx2]

# %%
sys.path.append(os.path.expanduser('~/git/Python/user_modules/'))
from match_coord import match_coord

idx1, idx2, d2d, d_ra, d_dec = match_coord(gaia['RA2000'], gaia['DEC2000'], twomass['RA'], twomass['DEC'], search_radius=0.5, plot_q=True)
print(len(idx1)/len(gaia))
print(len(idx1)/len(twomass))
# Out:
# Doubly matched objects = 4
# Final matched objects = 123643
# 0.9917781628003979
# 0.1092136875949546

# %%
gaia = gaia[idx1]
tycho2 = tycho2[idx1]
twomass = twomass[idx2]

# %%
gaia[:1]
# Out:
# <Table length=1>
#     SOURCE_ID              RA        ...       RA2000          DEC2000
#       int64             float64      ...      float64          float64
# ------------------ ----------------- ... ----------------- ----------------
# 215820835313697408 89.98790268039771 ... 89.98785938948015 53.1628508982043

# %% [markdown]
# ----------
# # zguss

# %%
plt.figure(figsize=(12, 12))
plt.plot((tycho2['VTmag']-twomass['Jmag']), gaia['decam_mag_z'] - tycho2['VTmag'], '.', ms=0.1, alpha=0.5)
plt.xlabel('VT - J')
plt.ylabel('DECam_z - VT')
plt.axis([-1, 7, -6, 1.5])
plt.grid(alpha=0.5)
plt.show()

plt.figure(figsize=(12, 12))
plt.plot((tycho2['VTmag']-twomass['Jmag']), gaia['decam_mag_z'] - tycho2['VTmag'], '.', ms=1, alpha=0.5)
plt.xlabel('VT - J')
plt.ylabel('DECam_z - VT')
# plt.axis([-1, 7, -6, 1.5])
plt.grid(alpha=0.5)
plt.show()

# %%
x, y = tycho2['VTmag']-twomass['Jmag'], gaia['decam_mag_z'] - tycho2['VTmag']

# %%
coeffs_z = np.polyfit(x, y, 2)
print(coeffs_z)
p = np.poly1d(coeffs_z)
# Out:
# [-0.01835938 -0.68084937  0.49222576]

# %%
xmin, xmax = -1, 8

# %%
x_plot = np.linspace(x.min(), x.max())
y_plot = p(np.clip(x_plot, xmin, xmax))

plt.figure(figsize=(12, 12))
plt.plot(tycho2['VTmag']-twomass['Jmag'], gaia['decam_mag_z'] - tycho2['VTmag'], '.', ms=1, alpha=1)
plt.plot(x_plot, y_plot, lw=1)
# plt.axis([-1, 8, -6, 1.5])
plt.xlabel('VT - J')
plt.ylabel('DECam_z - VT')
plt.grid(alpha=0.5)
plt.show()

zguess = p(np.clip(tycho2['VTmag']-twomass['Jmag'], xmin, xmax)) + tycho2['VTmag']
print(np.std(zguess-(gaia['decam_mag_z'])))
print(nmad(zguess-(gaia['decam_mag_z'])))

plt.figure(figsize=(12, 12))
plt.plot(tycho2['VTmag']-twomass['Jmag'], zguess-gaia['decam_mag_z'], '.', ms=1, alpha=0.1)
plt.xlabel('VT - J')
plt.ylabel('zguess - DECam_z')
plt.axis([-1, 8, -0.5, 0.5])
plt.grid(alpha=0.5)
plt.show()
# Out:
# 0.07494314
# 0.041614421081542965

# %% [markdown]
# ------
# # ggguess

# %%
plt.figure(figsize=(12, 12))
plt.plot((tycho2['VTmag']-twomass['Jmag']), gaia['PHOT_G_MEAN_MAG'] - tycho2['VTmag'], '.', ms=0.2, alpha=0.5)
plt.axis([-1, 7, -2.5, 0.5])
plt.xlabel('VT - J')
plt.ylabel('GAIA_G - VT')
plt.grid(alpha=0.5)
plt.show()

plt.figure(figsize=(12, 12))
plt.plot(tycho2['VTmag']-twomass['Jmag'], gaia['PHOT_G_MEAN_MAG'] - tycho2['VTmag'], '.', ms=0.5)
# plt.axis([-1, 7, -2.5, 0.5])
plt.xlabel('VT - J')
plt.ylabel('GAIA_G - VT')
plt.grid(alpha=0.5)
plt.show()

# %%
x, y = tycho2['VTmag']-twomass['Jmag'], gaia['PHOT_G_MEAN_MAG'] - tycho2['VTmag']

# %%
coeffs_gg = np.polyfit(x, y, 3)
print(coeffs_gg)
p = np.poly1d(coeffs_gg)
# Out:
# [ 0.00445346 -0.07819228 -0.07145574  0.00278177]

# %%
xmin, xmax = -1, 8

# %%
x_plot = np.linspace(x.min(), x.max())
y_plot = p(np.clip(x_plot, xmin, xmax))

plt.figure(figsize=(12, 12))
plt.plot(tycho2['VTmag']-twomass['Jmag'], gaia['PHOT_G_MEAN_MAG'] - tycho2['VTmag'], '.', ms=1, alpha=1)
plt.plot(x_plot, y_plot, lw=1)
# plt.axis([-1, 7, -2.5, 0.5])
plt.xlabel('VT - J')
plt.ylabel('GAIA_G - VT')
plt.grid(alpha=0.5)
plt.show()

ggguess = p(np.clip(tycho2['VTmag']-twomass['Jmag'], xmin, xmax)) + tycho2['VTmag']
print(np.std(ggguess-(gaia['PHOT_G_MEAN_MAG'])))
print(nmad(ggguess-(gaia['PHOT_G_MEAN_MAG'])))

plt.figure(figsize=(12, 12))
plt.plot(tycho2['VTmag']-twomass['Jmag'], ggguess-gaia['PHOT_G_MEAN_MAG'], '.', ms=1, alpha=0.1)
plt.axis([-1, 7, -0.5, 0.5])
plt.xlabel('VT - J')
plt.ylabel('ggguess - GAIA_G')
plt.grid(alpha=0.5)
plt.show()
# Out:
# 0.066202104
# 0.025925592041015622

# %% [markdown]
# -------

# %%
coeffs_z
# Out:
# array([-0.01835938, -0.68084937,  0.49222576])

# %%
coeffs_gg
# Out:
# array([ 0.00445346, -0.07819228, -0.07145574,  0.00278177])
